# %%
import nltk
import string

# %%
corpus=open('BeatlesCorpus.txt',encoding="utf-8").read()

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/alejandro/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alejandro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def remove_punctuation(text):
    return "".join([c for c in text if c not in string.punctuation])

# %%
from nltk.tokenize import RegexpTokenizer
from nltk import word_tokenize,sent_tokenize
def tokenize(text):
    return [list(map(str.lower,word_tokenize(sent))) for sent in sent_tokenize(text)]

# %%
corpusNP=remove_punctuation(corpus)
tokens=word_tokenize(corpusNP)
sent_tokens=sent_tokenize(corpusNP)
print(sent_tokens)
print("Tokens created: "+str(tokens.__len__()))
# Out:
# ['Our life together is so precious together We have grown  we have grown Although our love is still special Lets take our chance and fly away somewhere alone Its been so long since we took the time Noones to blame I know time flies so quikly But when I see you darling Its like we both are falling in love again Itll be just like starting over  starting over Everyday we used to make it love Why cant we be making love nice and easy Its time to spread our wings and fly Dont let another day go by my love Itll be just like starting over  starting over Why dont we take off alone Take a trip far far away Well be together on our own again Like we used to in the early days Well well well darling Its been so long since we took the time Noones to blame I know time flies so quikly But when I see you darling Its like we both are falling in love again Itll be just like starting over  starting over Everyday we used to make it love Why cant we be making love nice and easy Its time to spread our wings
# ...

# %%
NGRAMS=2
wordGrams=ngrams(tokens,NGRAMS)
print(threeGrams)
# Out:
# <generator object ngrams at 0x1240a6888>

# %%
'''https://kite.com/python/docs/nltk.ConditionalFreqDist'''
'''https://stackoverflow.com/questions/32676319/new-to-nltk-having-trouble-with-conditional-frequency'''

'''

PROBAR CON CONDITIONAL PROB DISTRIBUT
'''
from nltk.probability import ConditionalFreqDist
from nltk.probability import FreqDist
fDist = FreqDist(wordGrams)
print('10 Most common nGrams')
for i in range(0,10):
    print(fDist.most_common()[i])
# Out:
# 10 Most common nGrams
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-115-6f87b07c676e> in <module>()
#      11 print('10 Most common nGrams')
#      12 for i in range(0,10):
# ---> 13     print(fDist.most_common()[i])
#
# IndexError: list index out of range

# %%
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm import MLE
from nltk import ngrams

n=3
train_data,padded_sents=padded_everygram_pipeline(nGrams,tokens)
model=MLE(nGrams)
model.fit(train_data,padded_sents)

# %%
model.score('yellow', 'submarine'.split())
# Out:
# 0.5833333333333334
